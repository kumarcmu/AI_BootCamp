# %% [markdown]
# # Student Loan Risk with Deep Learning
#
# **Project 2**
# Kumaraswamy Srikantappa

# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student_loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/mbc/ai/m6/datasets/student_loans.csv"

sl_df = pd.read_csv(file_path)
# Review the DataFrame

sl_df.head(10)
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
# 5              7.4                0.66               0.00          1.8
# 6              7.9                0.60               0.06          1.6
# 7              7.3                0.65               0.00          1.2
# 8              7.8                0.58               0.02          2.0
# 9              7.5                0.50               0.36          6.1
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# ...

# %%
# Review the data types associated with the columns
sl_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column

y = sl_df["credit_ranking"].values

# Display a sample of y
y[:5]
# Out:
# array([5, 5, 5, 6, 5])

# %%
# Define features set X by selecting all columns but credit_ranking
X = sl_df.drop(columns=["credit_ranking"])

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1

X_train, X_test, y_train, y_test = train_test_split (X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance

X_scaler = StandardScaler()

# Fit the scaler to the features training dataset

X_scaler.fit(X_train)

# Fit the scaler to the features training dataset

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
number_of_features = 11

print(number_of_features)


# Review the number of features
# Out:
# 11

# %%
# Define the number of neurons in the output layer

number_of_classes = 1

# %%
# Define the number of hidden nodes for the first hidden layer

number_of_hidden_nodes_layer1 = 6

# Review the number hidden nodes in the first layer
print(number_of_hidden_nodes_layer1)
# Out:
# 6

# %%
# Define the number of hidden nodes for the second hidden layer
number_of_hidden_nodes_layer2 = 3


# Review the number hidden nodes in the second layer
print(number_of_hidden_nodes_layer2)
# Out:
# 3

# %%
# Create the Sequential model instance

deep_neuron = Sequential()

# %%
# Add the first hidden layer

deep_neuron.add(Dense(units=number_of_hidden_nodes_layer1, input_dim=number_of_features, activation='relu'))

# %%
# Add the second hidden layer
deep_neuron.add(Dense(units=number_of_hidden_nodes_layer2, activation='relu'))

# %%
# Add the output layer to the model specifying the number of output neurons and activation function
deep_neuron.add(Dense(units=number_of_classes, activation='linear'))

# %%
# Display the Sequential model summary

deep_neuron.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 6)                 72
#
#  dense_22 (Dense)            (None, 3)                 21
#
#  dense_23 (Dense)            (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `mse` loss function, the `adam` optimizer, and the `mse` evaluation metric.

# %%
# Compile the Sequential model
deep_neuron.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

# %%
# Fit the model using 50 epochs and the training data
deep_net_model = deep_neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 3ms/step - loss: 27.1523 - mse: 27.1523
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 23.5403 - mse: 23.5403
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.0539 - mse: 20.0539
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 16.6591 - mse: 16.6591
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 13.5253 - mse: 13.5253
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 10.7226 - mse: 10.7226
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 8.3449 - mse: 8.3449
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.3994 - mse: 6.3994
# Epoch 9/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.9136 - mse: 4.9136
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.8831 - mse: 3.8831
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data

model_loss, model_mse = deep_neuron.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results

print(f"Loss : {model_loss}, Accuracy : {model_mse}")
# Out:
# 13/13 - 0s - loss: 0.4518 - mse: 0.4518 - 152ms/epoch - 12ms/step
# Loss : 0.4517946243286133, Accuracy : 0.4517946243286133

# %% [markdown]
# ### Step 4: Save and export your model to an HDF5 file, and name the file `student_loans.h5`.

# %%
# Set the model's file path

#Ran this file in the Google Colab. Create a folder called "saved_models" in Colab under Files.

file_path = Path("saved_models/student_loans.h5")

# Export your model to a HDF5 file

deep_neuron.save(file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path


# Load the model to a new object

deep_neuron_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data.

# %%
# Make predictions on the testing data

sl_predictions = deep_neuron_imported.predict(X_test_scaled).round().astype("int32")

# Display the model loss and accuracy results

imported_model_loss, imported_model_mse = deep_neuron_imported.evaluate(X_test_scaled, y_test, verbose=2)


print(f"Loss : {imported_model_loss}, Accuracy : {imported_model_mse}")
# Out:
# 13/13 [==============================] - 0s 2ms/step
# 13/13 - 0s - loss: 0.4518 - mse: 0.4518 - 138ms/epoch - 11ms/step
# Loss : 0.4517946243286133, Accuracy : 0.4517946243286133

# %% [markdown]
# ### Step 3: Create a DataFrame to compare the predictions with the actual values.

# %%
# Create a DataFrame to compare the predictions with the actual values
sl_results = pd.DataFrame({"predictions": sl_predictions.ravel(), "actual": y_test})

# %% [markdown]
# ### Step 4: Display a sample of the DataFrame you created in step 3.

# %%
# Display sample data
sl_results.head(20)
# Out:
#     predictions  actual
# 0             5       5
# 1             5       6
# 2             6       6
# 3             6       6
# 4             7       6
# 5             6       6
# 6             6       6
# 7             4       5
# 8             6       5
# 9             5       5
# 10            7       6
# 11            5       6
# 12            5       6
# 13            7       6
# 14            5       6
# 15            5       5
# 16            6       6
# 17            5       5
# 18            6       5
# 19            6       5

# %% [markdown]
# ## **Comments on Predictions:** The Loss and Accuracy are pretty close to zero. If you notice the comparison between the predicted values from the imported model verses the actual values, many values are correctly predicted. We also notice some deviations. The model could be further refined by tuning the parameters.
